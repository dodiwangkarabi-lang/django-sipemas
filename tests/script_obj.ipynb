# %%
import os
import sys
import django

from pathlib import Path

BASE_DIR = fr"D:\PROGRAMMING\projects-skripsi\pengaduan_masyarakat\sipemas"
sys.path.append(BASE_DIR)

os.environ.setdefault("DJANGO_SETTINGS_MODULE", "sipemas.settings")
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"
django.setup()

# %% [markdown]
# models

# %%
from django.contrib.auth.models import User
from accounts.models import (
    Masyarakat
)

# %%
akun = User.objects.get(id=1)

# %%
akun.username
# Out:
# 'admin'

# %%
user = User.objects.get(id=2)
user.masyarakat
# Out:
# <Masyarakat: andi>
